# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/YRatzon/finel_project/main/ForbesAmericasTopColleges2019.csv'
coll_rank= pd.read_csv(url)

# %%
coll_rank
# Out:
#       Rank                                   Name         City State  \
# 0      1.0                     Harvard University    Cambridge    MA
# 1      2.0                    Stanford University     Stanford    CA
# 2      3.0                        Yale University    New Haven    CT
# 3      4.0  Massachusetts Institute of Technology    Cambridge    MA
# 4      5.0                   Princeton University    Princeton    NJ
# ..     ...                                    ...          ...   ...
# 645  646.0            New Mexico State University   Las Cruces    NM
# 646  647.0               Indiana State University  Terre Haute    IN
# 647  648.0              Emory &amp; Henry College        Emory    VA
# 648  649.0                          Wells College       Aurora    NY
# 649  650.0                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# ...

# %%
coll_rank.dtypes
# Out:
# Rank                        float64
# Name                         object
# City                         object
# State                        object
# Public/Private               object
# Undergraduate Population    float64
# Student Population          float64
# Net Price                   float64
# Average Grant Aid           float64
# Total Annual Cost           float64
# Alumni Salary               float64
# Acceptance Rate             float64
# SAT Lower                   float64
# SAT Upper                   float64
# ACT Lower                   float64
# ACT Upper                   float64
# Website                      object
# dtype: object

# %% [markdown]
# ### ניתן לראות כי המשתנים מתאימים להגדרות שלהם ולא צריך לסדר אותם

# %%
coll_rank.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         3
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    2
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# dtype: int64

# %% [markdown]
# #### בשלבים הבאים נמלא את הערכים החסרים בכל עמודה לפי מה שיתאים לה
# #### נבדוק על ידי גרפים מה מתאים למלא בכל עמודה

# %%
coll_rank.City = np.where(coll_rank.City.isnull(), coll_rank.State, coll_rank.City)
coll_rank.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         0
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    2
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# dtype: int64

# %%
sns.scatterplot(data= coll_rank, x= 'Net Price', y= 'Rank')
# Out:
# <AxesSubplot:xlabel='Net Price', ylabel='Rank'>

# %% [markdown]
# ##### ניתן לראות שאין קשר בין הסכום הסופי אל הדירוג ולכן נמלא בממוצע

# %%
coll_rank['Net Price']= coll_rank['Net Price'].fillna(coll_rank['Net Price'].mean())
coll_rank.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         0
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    0
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# dtype: int64

# %%
coll_rank['Website']= coll_rank['Website'].fillna('')
coll_rank.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         0
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    0
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      0
# dtype: int64

# %%
coll_rank
# Out:
#       Rank                                   Name         City State  \
# 0      1.0                     Harvard University    Cambridge    MA
# 1      2.0                    Stanford University     Stanford    CA
# 2      3.0                        Yale University    New Haven    CT
# 3      4.0  Massachusetts Institute of Technology    Cambridge    MA
# 4      5.0                   Princeton University    Princeton    NJ
# ..     ...                                    ...          ...   ...
# 645  646.0            New Mexico State University   Las Cruces    NM
# 646  647.0               Indiana State University  Terre Haute    IN
# 647  648.0              Emory &amp; Henry College        Emory    VA
# 648  649.0                          Wells College       Aurora    NY
# 649  650.0                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# ...
